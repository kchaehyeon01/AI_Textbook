# %%
import matplotlib.pyplot as plt
import mxnet as mx
from mxnet.gluon.data.vision import transforms

# %%
example_image = mx.image.imread("./data/catanddog/cat.jpg")
plt.imshow(example_image.asnumpy())

# %%
print(example_image.shape)
print(example_image[0].shape[0])
# Out:
# (1080, 1920, 3)
# 1920

# %%
# 불러온 이미지에 RandomResizedCrop을 적용하기 위한 함수를 생성
def show_images(imgs, num_rows, num_cols, scale=2):
    axpect_ratio = imgs[0].shape[0]/imgs[0].shape[1] # 확장할 이미지의 크기 조정
    figsize = (num_cols*scale, num_rows*scale*aspect_ratio)
